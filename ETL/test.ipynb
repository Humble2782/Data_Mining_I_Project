# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./data/model_ready/full_table-2023.csv', sep=';')
df_test = pd.read_csv('./data/newTest/E_feature_selection/E_feature_selection-2023.csv', sep=';')

# %%
df
# Out:
#         day  month  lighting_condition  location  intersection  \
# 0         7      5                   1         2             4
# 1         7      5                   5         2             1
# 2         7      5                   5         2             1
# 3         7      5                   1         2             3
# 4         7      5                   1         2             3
# ...     ...    ...                 ...       ...           ...
# 125784   26     10                   1         1             6
# 125785   26     10                   1         1             6
# 125786   20     10                   1         2             1
# 125787   20     10                   1         2             1
# 125788   20     10                   1         2             1
#
#         weather_condition  type_of_collision   latitude  longitude  hour  \
# 0                       2                  7  48.866386   2.323471     6
# ...

# %%
df_test.sort_index(axis=1).equals(df.sort_index(axis=1))
# Out:
# True
