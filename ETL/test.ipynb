# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_2019 = pd.read_csv('../data/new/feature_selection/feature_selection-2019.csv', sep=';')
df_2020 = pd.read_csv('../data/new/feature_selection/feature_selection-2020.csv', sep=';')

# %%
df_2019
# Out:
#         day  month  lighting_condition  location  intersection  \
# 0        30     11                   4         1             1
# 1        30     11                   4         1             1
# 2        30     11                   4         1             1
# 3        30     11                   3         1             1
# 4        28     11                   1         1             1
# ...     ...    ...                 ...       ...           ...
# 132972   27     11                   1         1             1
# 132973   30     11                   4         1             1
# 132974   30     11                   1         1             1
# 132975   29     11                   3         1             1
# 132976   29     11                   3         1             1
#
#         weather_condition  type_of_collision   latitude  longitude  \
# 0                       1                  2  48.896210   2.470120
# 1                       1                  2  48.896210   2.470120
# ...

# %%
df_2020
# Out:
#         day  month  lighting_condition  location  intersection  \
# 0         7      3                   1         2             3
# 1         7      3                   1         2             3
# 2         7      3                   2         2             9
# 3         7      3                   2         2             9
# 4         7      3                   1         2             2
# ...     ...    ...                 ...       ...           ...
# 105290   28     11                   1         1             1
# 105291   28     11                   1         1             1
# 105292   28     11                   1         1             1
# 105293   18     11                   4         2             1
# 105294   18     11                   4         2             1
#
#         weather_condition  type_of_collision   latitude  longitude  \
# 0                       1                  3  48.705350   2.438410
# 1                       1                  3  48.705350   2.438410
# ...
